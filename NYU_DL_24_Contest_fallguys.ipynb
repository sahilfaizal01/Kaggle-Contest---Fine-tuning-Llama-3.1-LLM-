# %% [markdown]
# # Math Question Answer Verification Competition
#
# ## Team: fallguys
#
# ### Members:
# * Sahil Faizal (sf4140)
# * Rohit Mohanty (rm6201)
# * Jack Chenghao Yang (cy2668)

# %% [markdown]
# Borrowed from [official Unsloth implementation](https://colab.research.google.com/drive/1Ys44kVvmeZtnICzWz0xgpRnrIOjZAuxp?usp=sharing#scrollTo=MKX_XKs_BNZR)

# %% [markdown]
# # **Installations**

# %%
import torch
print(torch.__version__)
import fastai
print(fastai.__version__)
# %%capture
# This cell will take time
# !pip install unsloth
# Also get the latest nightly Unsloth!
# !pip uninstall unsloth -y && pip install --upgrade --no-cache-dir "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# Out:
# 2.5.1+cu121
# 2.7.18
# Requirement already satisfied: unsloth in /usr/local/lib/python3.10/dist-packages (2024.11.7)
# Found existing installation: unsloth 2024.11.7
# Uninstalling unsloth-2024.11.7:
#   Successfully uninstalled unsloth-2024.11.7
# Collecting unsloth@ git+https://github.com/unslothai/unsloth.git (from unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git)
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-fnx78bqg/unsloth_306d8effbbe14ce29c1dab74e4af4bd4
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-fnx78bqg/unsloth_306d8effbbe14ce29c1dab74e4af4bd4
#   Resolved https://github.com/unslothai/unsloth.git to commit f26d4e739ed507de7a9088da53d10fd02f58d160
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: unsloth-zoo>=2024.11.1 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.11.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (24.2)
# Requirement already satisfied: tyro in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.8.14)
# Requirement already satisfied: transformers>=4.46.1 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.46.2)
# Requirement already satisfied: datasets>=2.16.0 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.1.0)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.66.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (5.9.5)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.45.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.26.4)
# Requirement already satisfied: protobuf<4.0.0 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.20.3)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.26.2)
# Requirement already satisfied: hf-transfer in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.1.8)
# Requirement already satisfied: bitsandbytes>=0.43.3 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.44.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.32.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.10.10)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.12.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.20.3)
# Requirement already satisfied: triton in /usr/local/lib/python3.10/dist-packages (from unsloth-zoo>=2024.11.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.1.0)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.10/dist-packages (from unsloth-zoo>=2024.11.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.1.1)
# Requirement already satisfied: trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9 in /usr/local/lib/python3.10/dist-packages (from unsloth-zoo>=2024.11.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.12.1)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from unsloth-zoo>=2024.11.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.13.2)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (13.9.4)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.7.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.17.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.0.2)
# Building wheels for collected packages: unsloth
#   Building wheel for unsloth (pyproject.toml) ... done
#   Created wheel for unsloth: filename=unsloth-2024.11.7-py3-none-any.whl size=163138 sha256=429af05d6de2980e1c580695958f11fff7b5b839ec0f5ebc0c0007cb788125ea
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_w176fvp/wheels/ed/d4/e9/76fb290ee3df0a5fc21ce5c2c788e29e9607a2353d8342fd0d
# Successfully built unsloth
# Installing collected packages: unsloth
# Successfully installed unsloth-2024.11.7

# %% [markdown]
# # **Loading the model**

# %%
from unsloth import FastLanguageModel
import torch

max_seq_length = 2048 # Setting the max sequence length param
dtype = None # None for auto detection
load_in_4bit = True # Use 4bit quantization to reduce memory usage
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.

# %%
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Meta-Llama-3.1-8B",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)
# Out:
# ==((====))==  Unsloth 2024.11.7: Fast Llama patching. Transformers = 4.46.2.
#    \\   /|    GPU: NVIDIA A100-SXM4-40GB. Max memory: 39.564 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.5.1+cu121. CUDA = 8.0. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.70G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/230 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/345 [00:00<?, ?B/s]

# %% [markdown]
# ## Load model and wrap with LoRA adapters

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 64, # rank of lora adapter
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 128,
    lora_dropout = 0, # lora dropout, 0 is optimized
    bias = "none",    # "none" is optimized
    use_gradient_checkpointing = "unsloth", # for very long context
    random_state = 3407,
    use_rslora = True,  # rank stabilized LoRA
    loftq_config = None, # LoftQ disabled
)
# Out:
# Unsloth 2024.11.7 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %% [markdown]
# ## Competition dataset

# %%
# download and load competition dataset

from datasets import load_dataset
dataset = load_dataset("ad6398/nyu-dl-teach-maths-comp")
# print and see dataset
dataset
# Out:
# README.md:   0%|          | 0.00/2.09k [00:00<?, ?B/s]
# train-00000-of-00002.parquet:   0%|          | 0.00/195M [00:00<?, ?B/s]
# train-00001-of-00002.parquet:   0%|          | 0.00/195M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/3.65M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1000000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'is_correct', 'answer', 'solution'],
#         num_rows: 1000000
#     })
#     test: Dataset({
#         features: ['question', 'is_correct', 'answer', 'solution'],
#         num_rows: 10000
#     })
# })

# %% [markdown]
# # **Creating the prompt template and loading the train dataset**

# %%
prompt = """As a renowned mathematician, determine if the given answer to the math question is correct. Respond strictly with 'True' or 'False' and provide no additional explanation.

### Question:
{}

### Solution:
{}

### Answer:
{}

### Output:
{}"""


EOS_TOKEN = tokenizer.eos_token


def formatting_prompts_func(examples):
    questions = examples["question"]
    solutions = examples["solution"]
    answers = examples["answer"]
    outputs = examples["is_correct"]
    texts = []
    for q, s, a, o in zip(questions, solutions, answers, outputs):
        text = prompt.format(q, s, a, o) + EOS_TOKEN
        texts.append(text)
    return {"text": texts}

train_dataset = dataset['train'].map(formatting_prompts_func, batched=True)
# Out:
# Map:   0%|          | 0/1000000 [00:00<?, ? examples/s]

# %%
#print a smaple training example
train_dataset['text'][0]
# Out:
# "As a renowned mathematician, determine if the given answer to the math question is correct. Respond strictly with 'True' or 'False' and provide no additional explanation.\n\n### Question:\nWhat is the radius of the circle inscribed in triangle $ABC$ if $AB = 22, AC=12,$ and $BC=14$? Express your answer in simplest radical form.\n\n### Solution:\nThe circle is inscribed in a triangle, and we know the sides of the triangle.\nTo use the inradius formula, we need to know the area of the triangle.\nWe can use Heron's formula to calculate the area.\n<llm-code>\nimport math\nfrom sympy import *\n\nAB, AC, BC = 22, 12, 14\n\n# Calculate the semiperimeter and area using Heron's formula\ns = (AB + AC + BC) / 2\nK = sqrt(s * (s - AB) * (s - AC) * (s - BC))\n\nprint(K)\n</llm-code>\n<llm-code-output>\n75.8946638440411\n</llm-code-output>\nLet's now use the formula for the radius of the inscribed circle.\n<llm-code>\nr = K / s\nprint(r)\n</llm-code>\n<llm-code-output>\n3.16227766016838\n</llm-code-output>\nThe answer is \\boxed{3.16227766016838}\n\n### Answer:\n3.16227766016838\n\n### Output:\nTrue<|end_of_text|>"

# %% [markdown]
# # **Installing and initiating the weights and biases monitoring tool**

# %%
# !pip install wandb
# Out:
# Requirement already satisfied: wandb in /usr/local/lib/python3.10/dist-packages (0.18.6)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.1.43)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from wandb) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.18.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (75.1.0)
# Requirement already satisfied: typing-extensions<5,>=4.4 in /usr/local/lib/python3.10/dist-packages (from wandb) (4.12.2)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2024.8.30)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)

# %%
wandb login(key="")
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# <iframe src='https://wandb.ai/sf4140-new-york-university/login(key="9b794da4e256240941e6d7732a8965e62e869566")/workspace?jupyter=true' style='border:none;width:100%;height:420px;'></iframe>

# %% [markdown]
# ## **SFT Param Setup**

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

training_args = TrainingArguments(
        per_device_train_batch_size=4,
        gradient_accumulation_steps=8,
        warmup_steps=2,
        max_steps=2500,
        learning_rate = 5e-5,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps =10,
        optim = "adamw_hf",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to = "wandb",
        save_strategy = "steps",
        save_steps = 100,
    )


trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = train_dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 4,
    packing = False, # Can make training 5x faster for short sequences.
    args = training_args
)
# Out:
# Map (num_proc=4):   0%|          | 0/1000000 [00:00<?, ? examples/s]
# max_steps is given, it will override any value given in num_train_epochs

# %% [markdown]
# # **Starting the model training**

# %%
trainer_stats = trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 1,000,000 | Num Epochs = 1
# O^O/ \_/ \    Batch size per device = 4 | Gradient Accumulation steps = 8
# \        /    Total batch size = 32 | Total steps = 2,500
#  "-____-"     Number of trainable parameters = 167,772,160
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Currently logged in as: sf4140 (sf4140-new-york-university). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>/content/wandb/run-20241115_234800-y7uibrrm</code>
# Syncing run <strong><a href='https://wandb.ai/sf4140-new-york-university/huggingface/runs/y7uibrrm' target="_blank">outputs</a></strong> to <a href='https://wandb.ai/sf4140-new-york-university/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/sf4140-new-york-university/huggingface' target="_blank">https://wandb.ai/sf4140-new-york-university/huggingface</a>
#  View run at <a href='https://wandb.ai/sf4140-new-york-university/huggingface/runs/y7uibrrm' target="_blank">https://wandb.ai/sf4140-new-york-university/huggingface/runs/y7uibrrm</a>
#     <div>
#
#       <progress value='613' max='2500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 613/2500 55:59 < 2:52:54, 0.18 it/s, Epoch 0.02/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>0.993300</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.751900</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.749300</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.701300</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.715900</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.690200</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.672300</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.717700</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.690700</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.713100</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.692900</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.721600</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.688700</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.672200</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.690000</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.675800</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.675900</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.659200</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.669900</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.666800</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.659100</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.660200</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.644100</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.616300</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.604800</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.649800</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.617600</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.642200</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.613800</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.662700</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.646600</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.615100</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.618400</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.615000</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.614000</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.624400</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.610800</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.617800</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.630900</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.608900</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.619200</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.595000</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.629900</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.597200</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.605800</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.616300</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.621900</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.610400</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.562900</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.609500</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>0.573400</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>0.597600</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>0.604400</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.596300</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.583300</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>0.596600</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>0.579200</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>0.599400</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>0.568200</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.550900</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>0.581600</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='2500' max='2500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2500/2500 3:47:07, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>0.993300</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.751900</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.749300</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.701300</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.715900</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.690200</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.672300</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.717700</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.690700</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.713100</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.692900</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.721600</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.688700</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.672200</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.690000</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.675800</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.675900</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.659200</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.669900</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.666800</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.659100</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.660200</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.644100</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.616300</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.604800</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.649800</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.617600</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.642200</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.613800</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.662700</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.646600</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.615100</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.618400</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.615000</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.614000</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.624400</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.610800</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.617800</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.630900</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.608900</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.619200</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.595000</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.629900</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.597200</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.605800</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.616300</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.621900</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.610400</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.562900</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.609500</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>0.573400</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>0.597600</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>0.604400</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.596300</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.583300</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>0.596600</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>0.579200</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>0.599400</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>0.568200</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.550900</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>0.581600</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>0.576000</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>0.584400</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>0.568000</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.570900</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>0.564700</td>
#     </tr>
#     <tr>
#       <td>670</td>
#       <td>0.578600</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>0.577400</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>0.558100</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.539900</td>
#     </tr>
#     <tr>
#       <td>710</td>
#       <td>0.569900</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>0.558600</td>
#     </tr>
#     <tr>
#       <td>730</td>
#       <td>0.569100</td>
#     </tr>
#     <tr>
#       <td>740</td>
#       <td>0.536200</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.537000</td>
#     </tr>
#     <tr>
#       <td>760</td>
#       <td>0.551200</td>
#     </tr>
#     <tr>
#       <td>770</td>
#       <td>0.549800</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>0.568200</td>
#     </tr>
#     <tr>
#       <td>790</td>
#       <td>0.531700</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.556500</td>
#     </tr>
#     <tr>
#       <td>810</td>
#       <td>0.549100</td>
#     </tr>
#     <tr>
#       <td>820</td>
#       <td>0.533300</td>
#     </tr>
#     <tr>
#       <td>830</td>
#       <td>0.549600</td>
#     </tr>
#     <tr>
#       <td>840</td>
#       <td>0.588200</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.530500</td>
#     </tr>
#     <tr>
#       <td>860</td>
#       <td>0.513700</td>
#     </tr>
#     <tr>
#       <td>870</td>
#       <td>0.529200</td>
#     </tr>
#     <tr>
#       <td>880</td>
#       <td>0.531000</td>
#     </tr>
#     <tr>
#       <td>890</td>
#       <td>0.514000</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.534400</td>
#     </tr>
#     <tr>
#       <td>910</td>
#       <td>0.526500</td>
#     </tr>
#     <tr>
#       <td>920</td>
#       <td>0.542100</td>
#     </tr>
#     <tr>
#       <td>930</td>
#       <td>0.507000</td>
#     </tr>
#     <tr>
#       <td>940</td>
#       <td>0.509500</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.532100</td>
#     </tr>
#     <tr>
#       <td>960</td>
#       <td>0.524500</td>
#     </tr>
#     <tr>
#       <td>970</td>
#       <td>0.508200</td>
#     </tr>
#     <tr>
#       <td>980</td>
#       <td>0.502500</td>
#     </tr>
#     <tr>
#       <td>990</td>
#       <td>0.508500</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.521100</td>
#     </tr>
#     <tr>
#       <td>1010</td>
#       <td>0.516000</td>
#     </tr>
#     <tr>
#       <td>1020</td>
#       <td>0.510500</td>
#     </tr>
#     <tr>
#       <td>1030</td>
#       <td>0.501000</td>
#     </tr>
#     <tr>
#       <td>1040</td>
#       <td>0.505100</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.497700</td>
#     </tr>
#     <tr>
#       <td>1060</td>
#       <td>0.487500</td>
#     </tr>
#     <tr>
#       <td>1070</td>
#       <td>0.499700</td>
#     </tr>
#     <tr>
#       <td>1080</td>
#       <td>0.481300</td>
#     </tr>
#     <tr>
#       <td>1090</td>
#       <td>0.500100</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.512800</td>
#     </tr>
#     <tr>
#       <td>1110</td>
#       <td>0.524400</td>
#     </tr>
#     <tr>
#       <td>1120</td>
#       <td>0.506300</td>
#     </tr>
#     <tr>
#       <td>1130</td>
#       <td>0.529200</td>
#     </tr>
#     <tr>
#       <td>1140</td>
#       <td>0.487400</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.515100</td>
#     </tr>
#     <tr>
#       <td>1160</td>
#       <td>0.468900</td>
#     </tr>
#     <tr>
#       <td>1170</td>
#       <td>0.497700</td>
#     </tr>
#     <tr>
#       <td>1180</td>
#       <td>0.524600</td>
#     </tr>
#     <tr>
#       <td>1190</td>
#       <td>0.494200</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.497100</td>
#     </tr>
#     <tr>
#       <td>1210</td>
#       <td>0.507000</td>
#     </tr>
#     <tr>
#       <td>1220</td>
#       <td>0.490500</td>
#     </tr>
#     <tr>
#       <td>1230</td>
#       <td>0.490600</td>
#     </tr>
#     <tr>
#       <td>1

# %% [markdown]
# ## **Performing inference**

# %%
# Sample inferene data point
test_dataset = dataset['test']

sample_ques = test_dataset['question'][0]
sample_sol = test_dataset['solution'][0]
sample_ans = test_dataset['answer'][0]

# %%
test_dataset[0]
# Out:
# {'question': 'The Parker family needs to leave the house by 5 pm for a dinner party. Mrs. Parker was waiting to get into the bathroom at 2:30 pm. Her oldest daughter used the bathroom for 45 minutes and her youngest daughter used the bathroom for another 30 minutes. Then her husband used it for 20 minutes. How much time will Mrs. Parker have to use the bathroom to leave on time?',
#  'is_correct': True,
#  'answer': '205',
#  'solution': "Let's solve this problem using Python code.\n<llm-code>\nminutes_per_hour = 60\nminutes_left_before_5 = 5 * minutes_per_hour\ntotal_time_spent_by_family = 45 + 30 + 20\nminutes_before_5_after_family = minutes_left_before_5 - total_time_spent_by_family\nminutes_before_5_after_family\n</llm-code>\n<llm-code-output>\n205\n</llm-code-output>\nThus Mrs. Parker will have \\boxed{205} minutes in the bathroom before the family leaves."}

# %%
sample_exp = test_dataset['solution'][0]

# %%
# Running inference on single test
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
input_prompt = prompt.format(
        sample_ques, # ques
        sample_ans, # given answer
        sample_exp,
        "", # output - leave this blank for generation! LLM willl generate is it is True or False
    )

print("Input Promt:\n", input_prompt)
inputs = tokenizer(
[
    input_prompt
], return_tensors = "pt").to("cuda")

input_shape = inputs['input_ids'].shape
input_token_len = input_shape[1] # 1 because of batch
outputs = model.generate(**inputs, max_new_tokens = 64, use_cache = True)
# you can get the whole generated text by uncommenting the below line
# text_generated = tokenizer.batch_decode([outputs, skip_special_tokens=True)

response = tokenizer.batch_decode([outputs[0][input_token_len:]], skip_special_tokens=True)
response
# Out:
# Input Promt:
#  As a renowned mathematician, determine if the given answer to the math question is correct. Respond strictly with 'True' or 'False' and provide no additional explanation.
#
# ### Question:
# The Parker family needs to leave the house by 5 pm for a dinner party. Mrs. Parker was waiting to get into the bathroom at 2:30 pm. Her oldest daughter used the bathroom for 45 minutes and her youngest daughter used the bathroom for another 30 minutes. Then her husband used it for 20 minutes. How much time will Mrs. Parker have to use the bathroom to leave on time?
#
# ### Solution:
# 205
#
# ### Answer:
# Let's solve this problem using Python code.
# <llm-code>
# minutes_per_hour = 60
# minutes_left_before_5 = 5 * minutes_per_hour
# total_time_spent_by_family = 45 + 30 + 20
# minutes_before_5_after_family = minutes_left_before_5 - total_time_spent_by_family
# minutes_before_5_after_family
# </llm-code>
# <llm-code-output>
# 205
# </llm-code-output>
# Thus Mrs. Parker will have \boxed{205} minutes in the bathroom before the family leaves.
#
# ### Output:
# ['False']

# %%
print(type(test_dataset))  # Should print a list or a dict
print(type(test_dataset[0]))  # Check the type of the first element in the dataset
# Out:
# <class 'datasets.arrow_dataset.Dataset'>
# <class 'dict'>

# %% [markdown]
# # **Saving the model**

# %%
model.save_pretrained("lora_model") # Local saving
tokenizer.save_pretrained("lora_model")
# Out:
# ('lora_model/tokenizer_config.json',
#  'lora_model/special_tokens_map.json',
#  'lora_model/tokenizer.json')

# %% [markdown]
# # **Running inference on test data**

# %%
batch_size = 10
predictions = []

model.eval()

for start_idx in range(0, len(test_dataset), batch_size):
    batch_samples = test_dataset[start_idx:start_idx + batch_size]
    batch_questions = batch_samples['question']
    batch_solutions = batch_samples['solution']
    batch_answers = batch_samples['answer']

    batch_prompts = [
        prompt.format(q, s, a, "")
        for q, s, a in zip(batch_questions, batch_solutions, batch_answers)
    ]


    inputs = tokenizer(
        batch_prompts,
        return_tensors="pt",
        padding=True,
        truncation=True,
        max_length=2048)


    with torch.no_grad():

      outputs = model.generate(
          input_ids=inputs['input_ids'],
          attention_mask=inputs['attention_mask'],
          max_new_tokens=256,
          do_sample=False,

      )

    for i in range(len(outputs)):
        input_len = inputs['input_ids'].shape[1]
        output_ids = outputs[i][input_len:]
        response = tokenizer.decode(output_ids, skip_special_tokens=True).strip()


        if response == "True":
            predictions.append("True")
        elif response == "False":
            predictions.append("False")
        else:
            predictions.append("False")

    torch.cuda.empty_cache()
    print(f"Processed {min(start_idx + batch_size, len(test_dataset))}/{len(test_dataset)} examples.")
# Out:
# Processed 10/10000 examples.
# Processed 20/10000 examples.
# Processed 30/10000 examples.
# Processed 40/10000 examples.
# Processed 50/10000 examples.
# Processed 60/10000 examples.
# Processed 70/10000 examples.
# Processed 80/10000 examples.
# Processed 90/10000 examples.
# Processed 100/10000 examples.
# Processed 110/10000 examples.
# Processed 120/10000 examples.
# Processed 130/10000 examples.
# Processed 140/10000 examples.
# Processed 150/10000 examples.
# Processed 160/10000 examples.
# Processed 170/10000 examples.
# Processed 180/10000 examples.
# Processed 190/10000 examples.
# Processed 200/10000 examples.
# Processed 210/10000 examples.
# Processed 220/10000 examples.
# Processed 230/10000 examples.
# Processed 240/10000 examples.
# Processed 250/10000 examples.
# Processed 260/10000 examples.
# Processed 270/10000 examples.
# Processed 280/10000 examples.
# Processed 290/10000 examples.
# Processed 300/10000 examples.
# Processed 310/10000 examples.
# Processed 320/10000 examples.
# Processed 330/10000 examples.
# Processed 340/10000 examples.
# Processed 350/10000 examples.
# Processed 360/10000 examples.
# Processed 370/10000 examples.
# Processed 380/10000 examples.
# Processed 390/10000 examples.
# Processed 400/10000 examples.
# Processed 410/10000 examples.
# Processed 420/10000 examples.
# Processed 430/10000 examples.
# Processed 440/10000 examples.
# Processed 450/10000 examples.
# Processed 460/10000 examples.
# Processed 470/10000 examples.
# Processed 480/10000 examples.
# Processed 490/10000 examples.
# Processed 500/10000 examples.
# Processed 510/10000 examples.
# Processed 520/10000 examples.
# Processed 530/10000 examples.
# Processed 540/10000 examples.
# Processed 550/10000 examples.
# Processed 560/10000 examples.
# Processed 570/10000 examples.
# Processed 580/10000 examples.
# Processed 590/10000 examples.
# Processed 600/10000 examples.
# Processed 610/10000 examples.
# Processed 620/10000 examples.
# Processed 630/10000 examples.
# Processed 640/10000 examples.
# Processed 650/10000 examples.
# Processed 660/10000 examples.
# Processed 670/10000 examples.
# Processed 680/10000 examples.
# Processed 690/10000 examples.
# Processed 700/10000 examples.
# Processed 710/10000 examples.
# Processed 720/10000 examples.
# Processed 730/10000 examples.
# Processed 740/10000 examples.
# Processed 750/10000 examples.
# Processed 760/10000 examples.
# Processed 770/10000 examples.
# Processed 780/10000 examples.
# Processed 790/10000 examples.
# Processed 800/10000 examples.
# Processed 810/10000 examples.
# Processed 820/10000 examples.
# Processed 830/10000 examples.
# Processed 840/10000 examples.
# Processed 850/10000 examples.
# Processed 860/10000 examples.
# Processed 870/10000 examples.
# Processed 880/10000 examples.
# Processed 890/10000 examples.
# Processed 900/10000 examples.
# Processed 910/10000 examples.
# Processed 920/10000 examples.
# Processed 930/10000 examples.
# Processed 940/10000 examples.
# Processed 950/10000 examples.
# Processed 960/10000 examples.
# Processed 970/10000 examples.
# Processed 980/10000 examples.
# Processed 990/10000 examples.
# Processed 1000/10000 examples.
# Processed 1010/10000 examples.
# Processed 1020/10000 examples.
# Processed 1030/10000 examples.
# Processed 1040/10000 examples.
# Processed 1050/10000 examples.
# Processed 1060/10000 examples.
# Processed 1070/10000 examples.
# Processed 1080/10000 examples.
# Processed 1090/10000 examples.
# Processed 1100/10000 examples.
# Processed 1110/10000 examples.
# Processed 1120/10000 examples.
# Processed 1130/10000 examples.
# Processed 1140/10000 examples.
# Processed 1150/10000 examples.
# Processed 1160/10000 examples.
# Processed 1170/10000 examples.
# Processed 1180/10000 examples.
# Processed 1190/10000 examples.
# Processed 1200/10000 examples.
# Processed 1210/10000 examples.
# Processed 1220/10000 examples.
# Processed 1230/10000 examples.
# Processed 1240/10000 examples.
# Processed 1250/10000 examples.
# Processed 1260/10000 examples.
# Processed 1270/10000 examples.
# Processed 1280/10000 examples.
# Processed 1290/10000 examples.
# Processed 1300/10000 examples.
# Processed 1310/10000 examples.
# Processed 1320/10000 examples.
# Processed 1330/10000 examples.
# Processed 1340/10000 examples.
# Processed 1350/10000 examples.
# Processed 1360/10000 examples.
# Processed 1370/10000 examples.
# Processed 1380/10000 examples.
# Processed 1390/10000 examples.
# Processed 1400/10000 examples.
# Processed 1410/10000 examples.
# Processed 1420/10000 examples.
# Processed 1430/10000 examples.
# Processed 1440/10000 examples.
# Processed 1450/10000 examples.
# Processed 1460/10000 examples.
# Processed 1470/10000 examples.
# Processed 1480/10000 examples.
# Processed 1490/10000 examples.
# Processed 1500/10000 examples.
# Processed 1510/10000 examples.
# Processed 1520/10000 examples.
# Processed 1530/10000 examples.
# Processed 1540/10000 examples.
# Processed 1550/10000 examples.
# Processed 1560/10000 examples.
# Processed 1570/10000 examples.
# Processed 1580/10000 examples.
# Processed 1590/10000 examples.
# Processed 1600/10000 examples.
# Processed 1610/10000 examples.
# Processed 1620/10000 examples.
# Processed 1630/10000 examples.
# Processed 1640/10000 examples.
# Processed 1650/10000 examples.
# Processed 1660/10000 examples.
# Processed 1670/10000 examples.
# Processed 1680/10000 examples.
# Processed 1690/10000 examples.
# Processed 1700/10000 examples.
# Processed 1710/10000 examples.
# Processed 1720/10000 examples.
# Processed 1730/10000 examples.
# Processed 1740/10000 examples.
# Processed 1750/10000 examples.
# Processed 1760/10000 examples.
# Processed 1770/10000 examples.
# Processed 1780/10000 examples.
# Processed 1790/10000 examples.
# Processed 1800/10000 examples.
# Processed 1810/10000 examples.
# Processed 1820/10000 examples.
# Processed 1830/10000 examples.
# Processed 1840/10000 examples.
# Processed 1850/10000 examples.
# Processed 1860/10000 examples.
# Processed 1870/10000 examples.
# Processed 1880/10000 examples.
# Processed 1890/10000 examples.
# Processed 1900/10000 examples.
# Processed 1910/10000 examples.
# Processed 1920/10000 examples.
# Processed 1930/10000 examples.
# Processed 1940/10000 examples.
# Processed 1950/10000 examples.
# Processed 1960/10000 examples.
# Processed 1970/10000 examples.
# Processed 1980/10000 examples.
# Processed 1990/10000 examples.
# Processed 2000/10000 examples.
# Processed 2010/10000 examples.
# Processed 2020/10000 examples.
# Processed 2030/10000 examples.
# Processed 2040/10000 examples.
# Processed 2050/10000 examples.
# Processed 2060/10000 examples.
# Processed 2070/10000 examples.
# Processed 2080/10000 examples.
# Processed 2090/10000 examples.
# Processed 2100/10000 examples.
# Processed 2110/10000 examples.
# Processed 2120/10000 examples.
# Processed 2130/10000 examples.
# Processed 2140/10000 examples.
# Processed 2150/10000 examples.
# Processed 2160/10000 examples.
# Processed 2170/10000 examples.
# Processed 2180/10000 examples.
# Processed 2190/10000 examples.
# Processed 2200/10000 examples.
# Processed 2210/10000 examples.
# Processed 2220/10000 examples.
# Processed 2230/10000 examples.
# Processed 2240/10000 examples.
# Processed 2250/10000 examples.
# Processed 2260/10000 examples.
# Processed 2270/10000 examples.
# Processed 2280/10000 examples.
# Processed 2290/10000 examples.
# Processed 2300/10000 examples.
# Processed 2310/10000 examples.
# Processed 2320/10000 examples.
# Processed 2330/10000 examples.
# Processed 2340/10000 examples.
# Processed 2350/10000 examples.
# Processed 2360/10000 examples.
# Processed 2370/10000 examples.
# Processed 2380/10000 examples.
# Processed 2390/10000 examples.
# Processed 2400/10000 examples.
# Processed 2410/10000 examples.
# Processed 2420/10000 examples.
# Processed 2430/10000 examples.
# Processed 2440/10000 examples.
# Processed 2450/10000 examples.
# Processed 2460/10000 examples.
# Processed 2470/10000 examples.
# Processed 2480/10000 examples.
# Processed 2490/10000 examples.
# Processed 2500/10000 examples.
# Processed 2510/10000 examples.
# Processed 2520/10000 examples.
# Processed 2530/10000 examples.
# Processed 2540/10000 examples.
# Processed 2550/10000 examples.
# Processed 2560/10000 examples.
# Processed 2570/10000 examples.
# Processed 2580/10000 examples.
# Processed 2590/10000 examples.
# Processed 2600/10000 examples.
# Processed 2610/10000 examples.
# Processed 2620/10000 examples.
# Processed 2630/10000 examples.
# Processed 2640/10000 examples.
# Processed 2650/10000 examples.
# Processed 2660/10000 examples.
# Processed 2670/10000 examples.
# Processed 2680/10000 examples.
# Processed 2690/10000 examples.
# Processed 2700/10000 examples.
# Processed 2710/10000 examples.
# Processed 2720/10000 examples.
# Processed 2730/10000 examples.
# Processed 2740/10000 examples.
# Processed 2750/10000 examples.
# Processed 2760/10000 examples.
# Processed 2770/10000 examples.
# Processed 2780/10000 examples.
# Processed 2790/10000 examples.
# Processed 2800/10000 examples.
# Processed 2810/10000 examples.
# Processed 2820/10000 examples.
# Processed 2830/10000 examples.
# Processed 2840/10000 examples.
# Processed 2850/10000 examples.
# Processed 2860/10000 examples.
# Processed 2870/10000 examples.
# Processed 2880/10000 examples.
# Processed 2890/10000 examples.
# Processed 2900/10000 examples.
# Processed 2910/10000 examples.
# Processed 2920/10000 examples.
# Processed 2930/10000 examples.
# Processed 2940/10000 examples.
# Processed 2950/10000 examples.
# Processed 2960/10000 examples.
# Processed 2970/10000 examples.
# Processed 2980/10000 examples.
# Processed 2990/10000 examples.
# Processed 3000/10000 examples.
# Processed 3010/10000 examples.
# Processed 3020/10000 examples.
# Processed 3030/10000 examples.
# Processed 3040/10000 examples.
# Processed 3050/10000 examples.
# Processed 3060/10000 examples.
# Processed 3070/10000 examples.
# Processed 3080/10000 examples.
# Processed 3090/10000 examples.
# Processed 3100/10000 examples.
# Processed 3110/10000 examples.
# Processed 3120/10000 examples.
# Processed 3130/10000 examples.
# Processed 3140/10000 examples.
# Processed 3150/10000 examples.
# Processed 3160/10000 examples.
# Processed 3170/10000 examples.
# Processed 3180/10000 examples.
# Processed 3190/10000 examples.
# Processed 3200/10000 examples.
# Processed 3210/10000 examples.
# Processed 3220/10000 examples.
# Processed 3230/10000 examples.
# Processed 3240/10000 examples.
# Processed 3250/10000 examples.
# Processed 3260/10000 examples.
# Processed 3270/10000 examples.
# Processed 3280/10000 examples.
# Processed 3290/10000 examples.
# Processed 3300/10000 examples.
# Processed 3310/10000 examples.
# Processed 3320/10000 examples.
# Processed 3330/10000 examples.
# Processed 3340/10000 examples.
# Processed 3350/10000 examples.
# Processed 3360/10000 examples.
# Processed 3370/10000 examples.
# Processed 3380/10000 examples.
# Processed 3390/10000 examples.
# Processed 3400/10000 examples.
# Processed 3410/10000 examples.
# Processed 3420/10000 examples.
# Processed 3430/10000 examples.
# Processed 3440/10000 examples.
# Processed 3450/10000 examples.
# Processed 3460/10000 examples.
# Processed 3470/10000 examples.
# Processed 3480/10000 examples.
# Processed 3490/10000 examples.
# Processed 3500/10000 examples.
# Processed 3510/10000 examples.
# Processed 3520/10000 examples.
# Processed 3530/10000 examples.
# Processed 3540/10000 examples.
# Processed 3550/10000 examples.
# Processed 3560/10000 examples.
# Processed 3570/10000 examples.
# Processed 3580/10000 examples.
# Processed 3590/10000 examples.
# Processed 3600/10000 examples.
# Processed 3610/10000 examples.
# Processed 3620/10000 examples.
# Processed 3630/10000 examples.
# Processed 3640/10000 examples.
# Processed 3650/10000 examples.
# Processed 3660/10000 examples.
# Processed 3670/10000 examples.
# Processed 3680/10000 examples.
# Processed 3690/10000 examples.
# Processed 3700/10000 examples.
# Processed 3710/10000 examples.
# Processed 3720/10000 examples.
# Processed 3730/10000 examples.
# Processed 3740/10000 examples.
# Processed 3750/10000 examples.
# Processed 3760/10000 examples.
# Processed 3770/10000 examples.
# Processed 3780/10000 examples.
# Processed 3790/10000 examples.
# Processed 3800/10000 examples.
# Processed 3810/10000 examples.
# Processed 3820/10000 examples.
# Processed 3830/10000 examples.
# Processed 3840/10000 examples.
# Processed 3850/10000 examples.
# Processed 3860/10000 examples.
# Processed 3870/10000 examples.
# Processed 3880/10000 examples.
# Processed 3890/10000 examples.
# Processed 3900/10000 examples.
# Processed 3910/10000 examples.
# Processed 3920/10000 examples.
# Processed 3930/10000 examples.
# Processed 3940/10000 examples.
# Processed 3950/10000 examples.
# Processed 3960/10000 examples.
# Processed 3970/10000 examples.
# Processed 3980/10000 examples.
# Processed 3990/10000 examples.
# Processed 4000/10000 examples.
# Processed 4010/10000 examples.
# Processed 4020/10000 examples.
# Processed 4030/10000 examples.
# Processed 4040/10000 examples.
# Processed 4050/10000 examples.
# Processed 4060/10000 examples.
# Processed 4070/10000 examples.
# Processed 4080/10000 examples.
# Processed 4090/10000 examples.
# Processed 4100/10000 examples.
# Processed 4110/10000 examples.
# Processed 4120/10000 examples.
# Processed 4130/10000 examples.
# Processed 4140/10000 examples.
# Processed 4150/10000 examples.
# Processed 4160/10000 examples.
# Processed 4170/10000 examples.
# Processed 4180/10000 examples.
# Processed 4190/10000 examples.
# Processed 4200/10000 examples.
# Processed 4210/10000 examples.
# Processed 4220/10000 examples.
# Processed 4230/10000 examples.
# Processed 4240/10000 examples.
# Processed 4250/10000 examples.
# Processed 4260/10000 examples.
# Processed 4270/10000 examples.
# Processed 4280/10000 examples.
# Processed 4290/10000 examples.
# Processed 4300/10000 examples.
# Processed 4310/10000 examples.
# Processed 4320/10000 examples.
# Processed 4330/10000 examples.
# Processed 4340/10000 examples.
# Processed 4350/10000 examples.
# Processed 4360/10000 examples.
# Processed 4370/10000 examples.
# Processed 4380/10000 examples.
# Processed 4390/10000 examples.
# Processed 4400/10000 examples.
# Processed 4410/10000 examples.
# Processed 4420/10000 examples.
# Processed 4430/10000 examples.
# Processed 4440/10000 examples.
# Processed 4450/10000 examples.
# Processed 4460/10000 examples.
# Processed 4470/10000 examples.
# Processed 4480/10000 examples.
# Processed 4490/10000 examples.
# Processed 4500/10000 examples.
# Processed 4510/10000 examples.
# Processed 4520/10000 examples.
# Processed 4530/10000 examples.
# Processed 4540/10000 examples.
# Processed 4550/10000 examples.
# Processed 4560/10000 examples.
# Processed 4570/10000 examples.
# Processed 4580/10000 examples.
# Processed 4590/10000 examples.
# Processed 4600/10000 examples.
# Processed 4610/10000 examples.
# Processed 4620/10000 examples.
# Processed 4630/10000 examples.
# Processed 4640/10000 examples.
# Processed 4650/10000 examples.
# Processed 4660/10000 examples.
# Processed 4670/10000 examples.
# Processed 4680/10000 examples.
# Processed 4690/10000 examples.
# Processed 4700/10000 examples.
# Processed 4710/10000 examples.
# Processed 4720/10000 examples.
# Processed 4730/10000 examples.
# Processed 4740/10000 examples.
# Processed 4750/10000 examples.
# Processed 4760/10000 examples.
# Processed 4770/10000 examples.
# Processed 4780/10000 examples.
# Processed 4790/10000 examples.
# Processed 4800/10000 examples.
# Processed 4810/10000 examples.
# Processed 4820/10000 examples.
# Processed 4830/10000 examples.
# Processed 4840/10000 examples.
# Processed 4850/10000 examples.
# Processed 4860/10000 examples.
# Processed 4870/10000 examples.
# Processed 4880/10000 examples.
# Processed 4890/10000 examples.
# Processed 4900/10000 examples.
# Processed 4910/10000 examples.
# Processed 4920/10000 examples.
# Processed 4930/10000 examples.
# Processed 4940/10000 examples.
# Processed 4950/10000 examples.
# Processed 4960/10000 examples.
# Processed 4970/10000 examples.
# Processed 4980/10000 examples.
# Processed 4990/10000 examples.
# Processed 5000/10000 examples.
# Processed 5010/10000 examples.
# Processed 5020/10000 examples.
# Processed 5030/10000 examples.
# Processed 5040/10000 examples.
# Processed 5050/10000 examples.
# Processed 5060/10000 examples.
# Processed 5070/10000 examples.
# Processed 5080/10000 examples.
# Processed 5090/10000 examples.
# Processed 5100/10000 examples.
# Processed 5110/10000 examples.
# Processed 5120/10000 examples.
# Processed 5130/10000 examples.
# Processed 5140/10000 examples.
# Processed 5150/10000 examples.
# Processed 5160/10000 examples.
# Processed 5170/10000 examples.
# Processed 5180/10000 examples.
# Processed 5190/10000 examples.
# Processed 5200/10000 examples.
# Processed 5210/10000 examples.
# Processed 5220/10000 examples.
# Processed 5230/10000 examples.
# Processed 5240/10000 examples.
# Processed 5250/10000 examples.
# Processed 5260/10000 examples.
# Processed 5270/10000 examples.
# Processed 5280/10000 examples.
# Processed 5290/10000 examples.
# Processed 5300/10000 examples.
# Processed 5310/10000 examples.
# Processed 5320/10000 examples.
# Processed 5330/10000 examples.
# Processed 5340/10000 examples.
# Processed 5350/10000 examples.
# Processed 5360/10000 examples.
# Processed 5370/10000 examples.
# Processed 5380/10000 examples.
# Processed 5390/10000 examples.
# Processed 5400/10000 examples.
# Processed 5410/10000 examples.
# Processed 5420/10000 examples.
# Processed 5430/10000 examples.
# Processed 5440/10000 examples.
# Processed 5450/10000 examples.
# Processed 5460/10000 examples.
# Processed 5470/10000 examples.
# Processed 5480/10000 examples.
# Processed 5490/10000 examples.
# Processed 5500/10000 examples.
# Processed 5510/10000 examples.
# Processed 5520/10000 examples.
# Processed 5530/10000 examples.
# Processed 5540/10000 examples.
# Processed 5550/10000 examples.
# Processed 5560/10000 examples.
# Processed 5570/10000 examples.
# Processed 5580/10000 examples.
# Processed 5590/10000 examples.
# Processed 5600/10000 examples.
# Processed 5610/10000 examples.
# Processed 5620/10000 examples.
# Processed 5630/10000 examples.
# Processed 5640/10000 examples.
# Processed 5650/10000 examples.
# Processed 5660/10000 examples.
# Processed 5670/10000 examples.
# Processed 5680/10000 examples.
# Processed 5690/10000 examples.
# Processed 5700/10000 examples.
# Processed 5710/10000 examples.
# Processed 5720/10000 examples.
# Processed 5730/10000 examples.
# Processed 5740/10000 examples.
# Processed 5750/10000 examples.
# Processed 5760/10000 examples.
# Processed 5770/10000 examples.
# Processed 5780/10000 examples.
# Processed 5790/10000 examples.
# Processed 5800/10000 examples.
# Processed 5810/10000 examples.
# Processed 5820/10000 examples.
# Processed 5830/10000 examples.
# Processed 5840/10000 examples.
# Processed 5850/10000 examples.
# Processed 5860/10000 examples.
# Processed 5870/10000 examples.
# Processed 5880/10000 examples.
# Processed 5890/10000 examples.
# Processed 5900/10000 examples.
# Processed 5910/10000 examples.
# Processed 5920/10000 examples.
# Processed 5930/10000 examples.
# Processed 5940/10000 examples.
# Processed 5950/10000 examples.
# Processed 5960/10000 examples.
# Processed 5970/10000 examples.
# Processed 5980/10000 examples.
# Processed 5990/10000 examples.
# Processed 6000/10000 examples.
# Processed 6010/10000 examples.
# Processed 6020/10000 examples.
# Processed 6030/10000 examples.
# Processed 6040/10000 examples.
# Processed 6050/10000 examples.
# Processed 6060/10000 examples.
# Processed 6070/10000 examples.
# Processed 6080/10000 examples.
# Processed 6090/10000 examples.
# Processed 6100/10000 examples.
# Processed 6110/10000 examples.
# Processed 6120/10000 examples.
# Processed 6130/10000 examples.
# Processed 6140/10000 examples.
# Processed 6150/10000 examples.
# Processed 6160/10000 examples.
# Processed 6170/10000 examples.
# Processed 6180/10000 examples.
# Processed 6190/10000 examples.
# Processed 6200/10000 examples.
# Processed 6210/10000 examples.
# Processed 6220/10000 examples.
# Processed 6230/10000 examples.
# Processed 6240/10000 examples.
# Processed 6250/10000 examples.
# Processed 6260/10000 examples.
# Processed 6270/10000 examples.
# Processed 6280/10000 examples.
# Processed 6290/10000 examples.
# Processed 6300/10000 examples.
# Processed 6310/10000 examples.
# Processed 6320/10000 examples.
# Processed 6330/10000 examples.
# Processed 6340/10000 examples.
# Processed 6350/10000 examples.
# Processed 6360/10000 examples.
# Processed 6370/10000 examples.
# Processed 6380/10000 examples.
# Processed 6390/10000 examples.
# Processed 6400/10000 examples.
# Processed 6410/10000 examples.
# Processed 6420/10000 examples.
# Processed 6430/10000 examples.
# Processed 6440/10000 examples.
# Processed 6450/10000 examples.
# Processed 6460/10000 examples.
# Processed 6470/10000 examples.
# Processed 6480/10000 examples.
# Processed 6490/10000 examples.
# Processed 6500/10000 examples.
# Processed 6510/10000 examples.
# Processed 6520/10000 examples.
# Processed 6530/10000 examples.
# Processed 6540/10000 examples.
# Processed 6550/10000 examples.
# Processed 6560/10000 examples.
# Processed 6570/10000 examples.
# Processed 6580/10000 examples.
# Processed 6590/10000 examples.
# Processed 6600/10000 examples.
# Processed 6610/10000 examples.
# Processed 6620/10000 examples.
# Processed 6630/10000 examples.
# Processed 6640/10000 examples.
# Processed 6650/10000 examples.
# Processed 6660/10000 examples.
# Processed 6670/10000 examples.
# Processed 6680/10000 examples.
# Processed 6690/10000 examples.
# Processed 6700/10000 examples.
# Processed 6710/10000 examples.
# Processed 6720/10000 examples.
# Processed 6730/10000 examples.
# Processed 6740/10000 examples.
# Processed 6750/10000 examples.
# Processed 6760/10000 examples.
# Processed 6770/10000 examples.
# Processed 6780/10000 examples.
# Processed 6790/10000 examples.
# Processed 6800/10000 examples.
# Processed 6810/10000 examples.
# Processed 6820/10000 examples.
# Processed 6830/10000 examples.
# Processed 6840/10000 examples.
# Processed 6850/10000 examples.
# Processed 6860/10000 examples.
# Processed 6870/10000 examples.
# Processed 6880/10000 examples.
# Processed 6890/10000 examples.
# Processed 6900/10000 examples.
# Processed 6910/10000 examples.
# Processed 6920/10000 examples.
# Processed 6930/10000 examples.
# Processed 6940/10000 examples.
# Processed 6950/10000 examples.
# Processed 6960/10000 examples.
# Processed 6970/10000 examples.
# Processed 6980/10000 examples.
# Processed 6990/10000 examples.
# Processed 7000/10000 examples.
# Processed 7010/10000 examples.
# Processed 7020/10000 examples.
# Processed 7030/10000 examples.
# Processed 7040/10000 examples.
# Processed 7050/10000 examples.
# Processed 7060/10000 examples.
# Processed 7070/10000 examples.
# Processed 7080/10000 examples.
# Processed 7090/10000 examples.
# Processed 7100/10000 examples.
# Processed 7110/10000 examples.
# Processed 7120/10000 examples.
# Processed 7130/10000 examples.
# Processed 7140/10000 examples.
# Processed 7150/10000 examples.
# Processed 7160/10000 examples.
# Processed 7170/10000 examples.
# Processed 7180/10000 examples.
# Processed 7190/10000 examples.
# Processed 7200/10000 examples.
# Processed 7210/10000 examples.
# Processed 7220/10000 examples.
# Processed 7230/10000 examples.
# Processed 7240/10000 examples.
# Processed 7250/10000 examples.
# Processed 7260/10000 examples.
# Processed 7270/10000 examples.
# Processed 7280/10000 examples.
# Processed 7290/10000 examples.
# Processed 7300/10000 examples.
# Processed 7310/10000 examples.
# Processed 7320/10000 examples.
# Processed 7330/10000 examples.
# Processed 7340/10000 examples.
# Processed 7350/10000 examples.
# Processed 7360/10000 examples.
# Processed 7370/10000 examples.
# Processed 7380/10000 examples.
# Processed 7390/10000 examples.
# Processed 7400/10000 examples.
# Processed 7410/10000 examples.
# Processed 7420/10000 examples.
# Processed 7430/10000 examples.
# Processed 7440/10000 examples.
# Processed 7450/10000 examples.
# Processed 7460/10000 examples.
# Processed 7470/10000 examples.
# Processed 7480/10000 examples.
# Processed 7490/10000 examples.
# Processed 7500/10000 examples.
# Processed 7510/10000 examples.
# Processed 7520/10000 examples.
# Processed 7530/10000 examples.
# Processed 7540/10000 examples.
# Processed 7550/10000 examples.
# Processed 7560/10000 examples.
# Processed 7570/10000 examples.
# Processed 7580/10000 examples.
# Processed 7590/10000 examples.
# Processed 7600/10000 examples.
# Processed 7610/10000 examples.
# Processed 7620/10000 examples.
# Processed 7630/10000 examples.
# Processed 7640/10000 examples.
# Processed 7650/10000 examples.
# Processed 7660/10000 examples.
# Processed 7670/10000 examples.
# Processed 7680/10000 examples.
# Processed 7690/10000 examples.
# Processed 7700/10000 examples.
# Processed 7710/10000 examples.
# Processed 7720/10000 examples.
# Processed 7730/10000 examples.
# Processed 7740/10000 examples.
# Processed 7750/10000 examples.
# Processed 7760/10000 examples.
# Processed 7770/10000 examples.
# Processed 7780/10000 examples.
# Processed 7790/10000 examples.
# Processed 7800/10000 examples.
# Processed 7810/10000 examples.
# Processed 7820/10000 examples.
# Processed 7830/10000 examples.
# Processed 7840/10000 examples.
# Processed 7850/10000 examples.
# Processed 7860/10000 examples.
# Processed 7870/10000 examples.
# Processed 7880/10000 examples.
# Processed 7890/10000 examples.
# Processed 7900/10000 examples.
# Processed 7910/10000 examples.
# Processed 7920/10000 examples.
# Processed 7930/10000 examples.
# Processed 7940/10000 examples.
# Processed 7950/10000 examples.
# Processed 7960/10000 examples.
# Processed 7970/10000 examples.
# Processed 7980/10000 examples.
# Processed 7990/10000 examples.
# Processed 8000/10000 examples.
# Processed 8010/10000 examples.
# Processed 8020/10000 examples.
# Processed 8030/10000 examples.
# Processed 8040/10000 examples.
# Processed 8050/10000 examples.
# Processed 8060/10000 examples.
# Processed 8070/10000 examples.
# Processed 8080/10000 examples.
# Processed 8090/10000 examples.
# Processed 8100/10000 examples.
# Processed 8110/10000 examples.
# Processed 8120/10000 examples.
# Processed 8130/10000 examples.
# Processed 8140/10000 examples.
# Processed 8150/10000 examples.
# Processed 8160/10000 examples.
# Processed 8170/10000 examples.
# Processed 8180/10000 examples.
# Processed 8190/10000 examples.
# Processed 8200/10000 examples.
# Processed 8210/10000 examples.
# Processed 8220/10000 examples.
# Processed 8230/10000 examples.
# Processed 8240/10000 examples.
# Processed 8250/10000 examples.
# Processed 8260/10000 examples.
# Processed 8270/10000 examples.
# Processed 8280/10000 examples.
# Processed 8290/10000 examples.
# Processed 8300/10000 examples.
# Processed 8310/10000 examples.
# Processed 8320/10000 examples.
# Processed 8330/10000 examples.
# Processed 8340/10000 examples.
# Processed 8350/10000 examples.
# Processed 8360/10000 examples.
# Processed 8370/10000 examples.
# Processed 8380/10000 examples.
# Processed 8390/10000 examples.
# Processed 8400/10000 examples.
# Processed 8410/10000 examples.
# Processed 8420/10000 examples.
# Processed 8430/10000 examples.
# Processed 8440/10000 examples.
# Processed 8450/10000 examples.
# Processed 8460/10000 examples.
# Processed 8470/10000 examples.
# Processed 8480/10000 examples.
# Processed 8490/10000 examples.
# Processed 8500/10000 examples.
# Processed 8510/10000 examples.
# Processed 8520/10000 examples.
# Processed 8530/10000 examples.
# Processed 8540/10000 examples.
# Processed 8550/10000 examples.
# Processed 8560/10000 examples.
# Processed 8570/10000 examples.
# Processed 8580/10000 examples.
# Processed 8590/10000 examples.
# Processed 8600/10000 examples.
# Processed 8610/10000 examples.
# Processed 8620/10000 examples.
# Processed 8630/10000 examples.
# Processed 8640/10000 examples.
# Processed 8650/10000 examples.
# Processed 8660/10000 examples.
# Processed 8670/10000 examples.
# Processed 8680/10000 examples.
# Processed 8690/10000 examples.
# Processed 8700/10000 examples.
# Processed 8710/10000 examples.
# Processed 8720/10000 examples.
# Processed 8730/10000 examples.
# Processed 8740/10000 examples.
# Processed 8750/10000 examples.
# Processed 8760/10000 examples.
# Processed 8770/10000 examples.
# Processed 8780/10000 examples.
# Processed 8790/10000 examples.
# Processed 8800/10000 examples.
# Processed 8810/10000 examples.
# Processed 8820/10000 examples.
# Processed 8830/10000 examples.
# Processed 8840/10000 examples.
# Processed 8850/10000 examples.
# Processed 8860/10000 examples.
# Processed 8870/10000 examples.
# Processed 8880/10000 examples.
# Processed 8890/10000 examples.
# Processed 8900/10000 examples.
# Processed 8910/10000 examples.
# Processed 8920/10000 examples.
# Processed 8930/10000 examples.
# Processed 8940/10000 examples.
# Processed 8950/10000 examples.
# Processed 8960/10000 examples.
# Processed 8970/10000 examples.
# Processed 8980/10000 examples.
# Processed 8990/10000 examples.
# Processed 9000/10000 examples.
# Processed 9010/10000 examples.
# Processed 9020/10000 examples.
# Processed 9030/10000 examples.
# Processed 9040/10000 examples.
# Processed 9050/10000 examples.
# Processed 9060/10000 examples.
# Processed 9070/10000 examples.
# Processed 9080/10000 examples.
# Processed 9090/10000 examples.
# Processed 9100/10000 examples.
# Processed 9110/10000 examples.
# Processed 9120/10000 examples.
# Processed 9130/10000 examples.
# Processed 9140/10000 examples.
# Processed 9150/10000 examples.
# Processed 9160/10000 examples.
# Processed 9170/10000 examples.
# Processed 9180/10000 examples.
# Processed 9190/10000 examples.
# Processed 9200/10000 examples.
# Processed 9210/10000 examples.
# Processed 9220/10000 examples.
# Processed 9230/10000 examples.
# Processed 9240/10000 examples.
# Processed 9250/10000 examples.
# Processed 9260/10000 examples.
# Processed 9270/10000 examples.
# Processed 9280/10000 examples.
# Processed 9290/10000 examples.
# Processed 9300/10000 examples.
# Processed 9310/10000 examples.
# Processed 9320/10000 examples.
# Processed 9330/10000 examples.
# Processed 9340/10000 examples.
# Processed 9350/10000 examples.
# Processed 9360/10000 examples.
# Processed 9370/10000 examples.
# Processed 9380/10000 examples.
# Processed 9390/10000 examples.
# Processed 9400/10000 examples.
# Processed 9410/10000 examples.
# Processed 9420/10000 examples.
# Processed 9430/10000 examples.
# Processed 9440/10000 examples.
# Processed 9450/10000 examples.
# Processed 9460/10000 examples.
# Processed 9470/10000 examples.
# Processed 9480/10000 examples.
# Processed 9490/10000 examples.
# Processed 9500/10000 examples.
# Processed 9510/10000 examples.
# Processed 9520/10000 examples.
# Processed 9530/10000 examples.
# Processed 9540/10000 examples.
# Processed 9550/10000 examples.
# Processed 9560/10000 examples.
# Processed 9570/10000 examples.
# Processed 9580/10000 examples.
# Processed 9590/10000 examples.
# Processed 9600/10000 examples.
# Processed 9610/10000 examples.
# Processed 9620/10000 examples.
# Processed 9630/10000 examples.
# Processed 9640/10000 examples.
# Processed 9650/10000 examples.
# Processed 9660/10000 examples.
# Processed 9670/10000 examples.
# Processed 9680/10000 examples.
# Processed 9690/10000 examples.
# Processed 9700/10000 examples.
# Processed 9710/10000 examples.
# Processed 9720/10000 examples.
# Processed 9730/10000 examples.
# Processed 9740/10000 examples.
# Processed 9750/10000 examples.
# Processed 9760/10000 examples.
# Processed 9770/10000 examples.
# Processed 9780/10000 examples.
# Processed 9790/10000 examples.
# Processed 9800/10000 examples.
# Processed 9810/10000 examples.
# Processed 9820/10000 examples.
# Processed 9830/10000 examples.
# Processed 9840/10000 examples.
# Processed 9850/10000 examples.
# Processed 9860/10000 examples.
# Processed 9870/10000 examples.
# Processed 9880/10000 examples.
# Processed 9890/10000 examples.
# Processed 9900/10000 examples.
# Processed 9910/10000 examples.
# Processed 9920/10000 examples.
# Processed 9930/10000 examples.
# Processed 9940/10000 examples.
# Processed 9950/10000 examples.
# Processed 9960/10000 examples.
# Processed 9970/10000 examples.
# Processed 9980/10000 examples.
# Processed 9990/10000 examples.
# Processed 10000/10000 examples.

# %% [markdown]
# # **Preparing predictions file**

# %%
import pandas as pd
# 创建提交文件
submission = pd.DataFrame({
    "ID": range(len(predictions)),
    "is_correct": predictions
})
submission.to_csv("/content/submission.csv", index=False)

print("Submission file saved as 'submission.csv'")
# Out:
# Submission file saved as 'submission.csv'

# %% [markdown]
# # **Downloading the model files**

# %%
import shutil
from google.colab import files

# Define the folder to zip and the output zip file name
folder_to_zip = 'lora_model'  # Replace with the folder you want to zip
zipped_file_name = 'lora_model.zip'  # Replace with your desired zip file name

# Zip the folder
shutil.make_archive(zipped_file_name.replace('.zip', ''), 'zip', folder_to_zip)

# Download the zip file
files.download(zipped_file_name)
